# %% [markdown]
# <a href="https://colab.research.google.com/github/andrefcmoraes/RelatividadeGeral/blob/main/Geodesicas_MS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Métrica de Schwarzschild
# ![D5kBplVXoAIts5u.jpg](data:image/jpeg;base64,...)
#
# ![img1109.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from google.colab import files
# %matplotlib inline

# %%
Rs = 1
def function(x,tau):
  return [-(Rs/(Rs*x[3]-x[3]**2))*x[0]*x[2],
          x[0],
          -0.5*(Rs/(x[3]**2)-(Rs**2)/(x[3]**3))*x[0]**2 -0.5*(-Rs/(x[3]-Rs)**2 + Rs**2/(x[3]*(x[3]-Rs)**2))*x[2]**2-(Rs-x[3])*x[4]**2,
          x[2],
          -(2/x[3])*x[2]*x[4],
          x[4]]
tau = np.linspace(0,200,10**6)
radious = 5
ci = [1/np.sqrt(1-Rs/radious), 0, 0, radious, 0.09, 0]
X = odeint(function, ci, tau)
x = X[:,3]*np.cos(X[:,5])
y = X[:,3]*np.sin(X[:,5])
figure, axes = plt.subplots()
draw_circle = plt.Circle((0, 0), Rs, color='black')
plt.plot(x,y)
axes.set_aspect(1)
draw_circle2 = plt.Circle((0,0), 1.5*Rs,fill=False,ec="red")
axes.set_aspect(1)
axes.add_artist(draw_circle2)
axes.add_artist(draw_circle)
plt.title('Buraco negro Rs = 1')
plt.show()

# %%
Rs = 1
radious = 1.5*Rs
def function(x,tau):
  return [-(Rs/(Rs*x[3]-x[3]**2))*x[0]*x[2],
          x[0],
          -0.5*(Rs/(x[3]**2)-(Rs**2)/(x[3]**3))*x[0]**2 -0.5*(-Rs/(x[3]-Rs)**2 + Rs**2/(x[3]*(x[3]-Rs)**2))*x[2]**2-(Rs-x[3])*x[4]**2,
          x[2],
          -(2/x[3])*x[2]*x[4],
          x[4]]
tau = np.linspace(0,30,10**6)
ci = [1/np.sqrt(1-Rs/radious), 0, -0.3, radious, 1, 0]
X = odeint(function, ci, tau)
x = X[:,3]*np.cos(X[:,5])
y = X[:,3]*np.sin(X[:,5])
figure, axes = plt.subplots()
draw_circle = plt.Circle((0, 0), Rs, color='black')
plt.plot(x,y)
axes.set_aspect(1)
draw_circle2 = plt.Circle((0,0), 1.5*Rs,fill=False,ec="red")
axes.set_aspect(1)
axes.add_artist(draw_circle2)
axes.add_artist(draw_circle)
plt.ylim((-3,3))
plt.xlim((-2.5,2.5))
plt.title('Buraco negro Rs = 1')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

# %%
Rs = 5
x0 = -9.2
radious = 1.5*Rs
def function(x,tau):
  return [-(Rs/(Rs*x[3]-x[3]**2))*x[0]*x[2],
          x[0],
          -0.5*(Rs/(x[3]**2)-(Rs**2)/(x[3]**3))*x[0]**2 -0.5*(-Rs/(x[3]-Rs)**2 + Rs**2/(x[3]*(x[3]-Rs)**2))*x[2]**2-(Rs-x[3])*x[4]**2,
          x[2],
          -(2/x[3])*x[2]*x[4],
          x[4]]
tau = np.linspace(0,100,10**6)
################################################################################
Z = []
def f(b):
  ci = [1/np.sqrt(1-Rs/np.sqrt(x0**2+b**2)), 0, x0/np.sqrt(x0**2+b), np.sqrt(x0**2+b**2), 0.08, np.arccos(x0/np.sqrt(x0**2+b))]
  X = odeint(function, ci, tau)
  return Z.append(X)
F = []

NX = []
NY = []
for i in range(100):
  f(0.5*i+5)
  NX.append(Z[i][:,3]*np.cos(Z[i][:,5]))
  NY.append(Z[i][:,3]*np.sin(Z[i][:,5]))

figure, axes = plt.subplots()
for n in range(100):
  plt.plot(NX[n],NY[n], color = 'black')
draw_circle = plt.Circle((0, 0), Rs, color='black')
axes.set_aspect(1)
draw_circle2 = plt.Circle((0,0), 1.5*Rs,fill=False,ec="red")
axes.set_aspect(1)
axes.add_artist(draw_circle2)
axes.add_artist(draw_circle)
plt.ylim((-30,30))
plt.xlim((-30,30))
plt.title('Buraco negro Rs = 5')
plt.show()
